# %% [markdown]
# ### Analiza i Przetwarzanie Dźwięku
# **Projekt 2** - Szymon Gut, Jan Krężel

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.recording import *
from src.plots import *
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# muzyka
africa = Recording("recordings/africa_toto.wav")
cantina = Recording("recordings/cantina_band.wav")
panther = Recording("recordings/pink_panther.wav")
starwars = Recording("recordings/starwars.wav")

# mowa
female = Recording("recordings/female.wav")
male = Recording("recordings/male.wav")
gettysburg = Recording("recordings/gettysburg.wav")
sentence = Recording("recordings/zdanie_1.wav")
harvard_denoised = Recording("recordings/harvard_denoised.wav")

# %%
chrzaszcz = Recording('recordings/jk_znormalizowane/chrząszcz_1.wav')
omoltyk = Recording('recordings/jk_znormalizowane/omoltyk_1.wav')
zdanie = Recording('recordings/jk_znormalizowane/zdanie_1.wav')
high_pitch = Recording('recordings/high-pitch-sound.wav')
nine = Recording('recordings/jk_znormalizowane/dziewięć_1.wav')
ten = Recording('recordings/jk_znormalizowane/dziesięć_1.wav')
oga = Recording('recordings/jk_znormalizowane/oga_1.wav')
owoc = Recording('recordings/jk_znormalizowane/owoc_1.wav')

# %% [markdown]
# ### FFT Dla całego nagrania

# %% [markdown]
# **Nagranie ze zdaniem**

# %%
plot_frequency(zdanie, 1e6, 0.1)

# %% [markdown]
# **Nagranie z dźwiękiem o wysokiej częstotilowości**

# %%
plot_frequency(high_pitch, 1e6, 0.5)

# %% [markdown]
# **Nagranie z muzyką**

# %%
plot_frequency(africa, 1e7, alpha=0.05)

# %%
plot_frequency(cantina, 1e5)

# %% [markdown]
# **Pojedyncze słowa**

# %%
plot_frequency(chrzaszcz, 1e5, alpha=0.2)

# %%
plot_frequency(omoltyk, 1e5, alpha=0.2)

# %% [markdown]
# ### FFT dla ramek

# %% [markdown]
# **Zdanie**

# %%
zdanie.set_window_function('identity')
plot_frame_frequency(zdanie, 100, 1e2, alpha=0.8)

# %%
zdanie.set_window_function('triangle')
plot_frame_frequency(zdanie, 100, 1e2, alpha=0.8)

# %%
zdanie.set_window_function('blackman')
plot_frame_frequency(zdanie, 100, 1e2, alpha=0.8)

# %% [markdown]
# **Muzyka**

# %%
cantina.set_window_function('identity')
plot_frame_frequency(cantina, 100, 1e2, alpha=0.5)

# %%
cantina.set_window_function('triangle')
plot_frame_frequency(cantina, 100, 1e2, alpha=0.5)

# %% [markdown]
# ### Frequency Centroid

# %% [markdown]
# **Zdanie**

# %%
plot_FC(male)

# %% [markdown]
# **Muzyka**

# %%
plot_FC(cantina, alpha=1.0)

# %% [markdown]
# ### Effective Bandwidth

# %% [markdown]
# **Zdanie**

# %%
plot_BW(zdanie, alpha=1.0)

# %%
plot_BW(cantina, alpha=1.0)

# %%
plot_zcr(cantina)

# %%
ax = sns.scatterplot(x=cantina.BW(), y=cantina.get_zcr_array(), alpha=0.1)
ax.set(xlabel='BW', ylabel='ZCR')
# Out:
# [Text(0.5, 0, 'BW'), Text(0, 0.5, 'ZCR')]

# %% [markdown]
# ### Spectral Flatness Measure

# %%
plot_SFM(zdanie)

# %% [markdown]
# ### Spectral Crest Factor

# %%
plot_SCF(zdanie)

# %% [markdown]
# ### Band Energy Ratio

# %%
zdanie.set_window_function('identity')
plot_ERSB(zdanie)

# %%
zdanie.set_window_function('hamming')
plot_ERSB(zdanie)

# %%
panther.set_window_function('identity')
plot_ERSB(panther, alpha=0.7)
# Out:
# c:\MyRoot\PWFiles\semestr 6\APD\projekt1\src\recording.py:263: RuntimeWarning: invalid value encountered in divide
#   return self.BE(freq_lower_bound, freq_upper_bound) / \

# %%
panther.set_window_function('triangle')
plot_ERSB(panther, alpha=0.7)
# Out:
# c:\MyRoot\PWFiles\semestr 6\APD\projekt1\src\recording.py:263: RuntimeWarning: invalid value encountered in divide
#   return self.BE(freq_lower_bound, freq_upper_bound) / \

# %% [markdown]
# ### Spektrogram

# %%
plot_spectrogram(zdanie, 441, 200, wn.triang)

# %%
plot_spectrogram(zdanie, 441, 200, wn.hann)

# %%
plot_spectrogram(high_pitch, 882, 0, wn.hann)

# %%
plot_spectrogram(high_pitch, 882, 0, wn.hamming)

# %%
plot_spectrogram(chrzaszcz, 441, 200, wn.triang)

# %%
plot_spectrogram(omoltyk, 441, 200, wn.triang)

# %%
plot_spectrogram(oga, 441, 200, wn.triang)

# %%
plot_spectrogram(owoc, 441, 200, wn.triang)

# %%
plot_spectrogram(nine, 441, 200, wn.triang)

# %%
plot_spectrogram(ten, 441, 200, wn.triang)
